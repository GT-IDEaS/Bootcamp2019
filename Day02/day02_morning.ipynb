# %%
import numpy as np

# %%
data = {i : np.random.randn() for i in range(7)}

# %%
data
# Out:
# {0: -0.8969138449478083,
#  1: -0.9030884258855836,
#  2: -0.9187519182049295,
#  3: -1.2050784277653532,
#  4: 0.8871366326272345,
#  5: -0.5943559874066564,
#  6: -0.8980359420234009}

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot([1,2,3,4,5,15],[-1,4,-9,16,-25,2])
plt.show()
