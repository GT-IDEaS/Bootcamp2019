# %%
#numpy example
import numpy as np

# %%
data = {i : np.random.randn() for i in range(7)}
#is this a dictionary comprehension???

# %%
print(data)
# Out:
# {0: -0.09142961806407045, 1: -0.3396568453502927, 2: 0.15305062936848143, 3: 1.425627007877568, 4: 0.08306541093449475, 5: 0.9342631614234368, 6: -1.46480982198689}

# %%
#matplotlib example
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
plt.plot(range(100), [math.sin(x/5) for x in range(100)])
plt.show()
