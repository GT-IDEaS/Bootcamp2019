# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {i : np.random.randn() for i in range(7)}

# %%
data
# Out:
# {0: 0.7342810311420467,
#  1: -2.2185044266045066,
#  2: -0.9177924115413029,
#  3: -1.280128500206725,
#  4: 0.6964342911012517,
#  5: 0.9217313398663088,
#  6: 1.5480063734025402}

# %%
plt.plot([1,2,3,4],[19,42,9,17])
plt.show()
